# %%
# pip install mpld3
# Out:
# Note: you may need to restart the kernel to use updated packages.
# 'C:\Users\Krishna' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import nltk
import pandas as pd
import numpy as np

# %matplotlib inline
# import mpld3
# mpld3.enable_notebook()
import matplotlib.pyplot as plt
import string
from nltk.tokenize import TweetTokenizer

from sklearn.preprocessing import Normalizer

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD, PCA
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer

from sklearn.cluster import KMeans

from collections import Counter

# %%
# path = "../Pre-Processing/"

# %%
# data = pd.read_csv(path+'Pre_Processed_Data.csv')
# data_without_stemming = pd.read_csv(path+'Pre_Processed_Data_without_stemming.csv')

# # data
# data = data_without_stemming
# data
# Out:
#        Unnamed: 0 Submission Date  \
# 0               0     30-Sep-2020
# 1               1     24-Sep-2020
# 2               2     19-Sep-2020
# 3               3     15-Sep-2020
# 4               4     15-Sep-2020
# ...           ...             ...
# 17979       17979      1-Jun-1963
# 17980       17980      5-May-1963
# 17981       17981      4-May-1963
# 17982       17982     21-Dec-  18
# 17983       17983     22-Jul-   7
#
#                                                    Title  \
# 0      Generative Models for Zero-Shot and Generalize...
# 1      Recrystallization As a Defect Healing Techniqu...
# 2      Development of a rapid soil testing tool for r...
# 3      Optimal Hybrid Precoder Designs for the Linear...
# 4      Discernment of the Induced Third Order Optical...
# ...                                                  ...
# 17979  NUCLEAR MAGNETIC RESONANCE SPECTRA OF SOME SUB...
# 17980  CONTRIBUTIONS TO TWO-DIMENSIONAL INCLUSION PRO...
# 17981  A STUDY IN INTEGRAL FUNCTION AND THEIR DERIVAT...
# 17982  Modeling, hardware-in-the-loop simulation and ...
# 17983  Identification and Application of a Green Inhi...
#
#                      Author             Supervisor   Degree    Department  \
# 0        Verma, Vinay Kumar            Rai, Piyush    PH.D.           CSE
# 1           Vishal, Utkarsh      Shekhar, Shashank  M.TECH.           MSE
# 2              Ahmad, Ashar        Singh, Jayant K  M.TECH.           CHE
# 3        Raghubabu, Akarapu  Jagannatham, Aditya K  M.TECH.            EE
# 4         Chaturvedi, Umang     Goswami, Debabrata  M.TECH.          CELP
# ...                     ...                    ...      ...           ...
# 17979           Aruldhas, G  Venkateswarlu, Putcha    PH.D.           PHY
# 17980        Radha, Krishna          Bhargava, R D    PH.D.  MATH & STATS
# 17981  Gupta, Jagdish Saran      Srivastava, R S L    PH.D.  MATH & STATS
# 17982           Setu, Sagar               Abhishek    PH.D.            AE
# 17983         Dobhal, Harsh          Misra, Sudhir  M.TECH.            CE
#
#                                                 Abstract
# 0      ['zero-shot', 'learning', 'problem', 'learning...
# 1      ['current', 'world', 'major', 'focus', 'design...
# 2      ['rapid', 'increase', 'population', 'decline',...
# 3      ['internet', 'things', 'iot', 'prominent', 'te...
# 4      ['thesis', 'presents', 'nonlinear', 'optical',...
# ...                                                  ...
# 17979                                       ['abstract']
# 17980                                       ['abstract']
# 17981                                       ['abstract']
# 17982  ['unmanned', 'aerial', 'vehicle', 'uavs', 'tod...
# 17983  ['reinforcement', 'corrosion', 'concrete', 'ei...
#
# [17984 rows x 8 columns]

# %% [markdown]
# ### deleting entries in which Departments are not  mentioned

# %%
# data = data[data['Department']!='-'].reset_index(drop=True)
# data
# Out:
#        Unnamed: 0 Submission Date  \
# 0               0     30-Sep-2020
# 1               1     24-Sep-2020
# 2               2     19-Sep-2020
# 3               3     15-Sep-2020
# 4               4     15-Sep-2020
# ...           ...             ...
# 17976       17979      1-Jun-1963
# 17977       17980      5-May-1963
# 17978       17981      4-May-1963
# 17979       17982     21-Dec-  18
# 17980       17983     22-Jul-   7
#
#                                                    Title  \
# 0      Generative Models for Zero-Shot and Generalize...
# 1      Recrystallization As a Defect Healing Techniqu...
# 2      Development of a rapid soil testing tool for r...
# 3      Optimal Hybrid Precoder Designs for the Linear...
# 4      Discernment of the Induced Third Order Optical...
# ...                                                  ...
# 17976  NUCLEAR MAGNETIC RESONANCE SPECTRA OF SOME SUB...
# 17977  CONTRIBUTIONS TO TWO-DIMENSIONAL INCLUSION PRO...
# 17978  A STUDY IN INTEGRAL FUNCTION AND THEIR DERIVAT...
# 17979  Modeling, hardware-in-the-loop simulation and ...
# 17980  Identification and Application of a Green Inhi...
#
#                      Author             Supervisor   Degree    Department  \
# 0        Verma, Vinay Kumar            Rai, Piyush    PH.D.           CSE
# 1           Vishal, Utkarsh      Shekhar, Shashank  M.TECH.           MSE
# 2              Ahmad, Ashar        Singh, Jayant K  M.TECH.           CHE
# 3        Raghubabu, Akarapu  Jagannatham, Aditya K  M.TECH.            EE
# 4         Chaturvedi, Umang     Goswami, Debabrata  M.TECH.          CELP
# ...                     ...                    ...      ...           ...
# 17976           Aruldhas, G  Venkateswarlu, Putcha    PH.D.           PHY
# 17977        Radha, Krishna          Bhargava, R D    PH.D.  MATH & STATS
# 17978  Gupta, Jagdish Saran      Srivastava, R S L    PH.D.  MATH & STATS
# 17979           Setu, Sagar               Abhishek    PH.D.            AE
# 17980         Dobhal, Harsh          Misra, Sudhir  M.TECH.            CE
#
#                                                 Abstract
# 0      ['zero-shot', 'learning', 'problem', 'learning...
# 1      ['current', 'world', 'major', 'focus', 'design...
# 2      ['rapid', 'increase', 'population', 'decline',...
# 3      ['internet', 'things', 'iot', 'prominent', 'te...
# 4      ['thesis', 'presents', 'nonlinear', 'optical',...
# ...                                                  ...
# 17976                                       ['abstract']
# 17977                                       ['abstract']
# 17978                                       ['abstract']
# 17979  ['unmanned', 'aerial', 'vehicle', 'uavs', 'tod...
# 17980  ['reinforcement', 'corrosion', 'concrete', 'ei...
#
# [17981 rows x 8 columns]

# %% [markdown]
# ### Taking Top 30 values from tf-idf vectorization --  importing data

# %%
data = pd.read_csv('Data_topn.csv')
data = data.rename(columns={'Abstract_Topn':'Abstract'})
data
# Out:
#        Unnamed: 0 Submission Date  \
# 0               0     30-Sep-2020
# 1               1     24-Sep-2020
# 2               2     19-Sep-2020
# 3               3     15-Sep-2020
# 4               4     15-Sep-2020
# ...           ...             ...
# 17288       17288     25-Apr-1964
# 17289       17289     25-Feb-1964
# 17290       17290     29-Dec-1963
# 17291       17291     21-Dec-  18
# 17292       17292     22-Jul-   7
#
#                                                    Title              Author  \
# 0      Generative Models for Zero-Shot and Generalize...  Verma, Vinay Kumar
# 1      Recrystallization As a Defect Healing Techniqu...     Vishal, Utkarsh
# 2      Development of a rapid soil testing tool for r...        Ahmad, Ashar
# 3      Optimal Hybrid Precoder Designs for the Linear...  Raghubabu, Akarapu
# 4      Discernment of the Induced Third Order Optical...   Chaturvedi, Umang
# ...                                                  ...                 ...
# 17288  CONTRIBUTIONS TO HYDRODYNAMIC AND HYDROMAGNETI...         Shukla, J B
# 17289  STEADY AND UNSTEADY FLOWS OF NEWTONIAN, NON-NE...     Srivastava, P N
# 17290  CONTINUOUS WAVE NON-LINEAR OPTICAL STUDIES IN ...     Rao, K Divakara
# 17291  Modeling, hardware-in-the-loop simulation and ...         Setu, Sagar
# 17292  Identification and Application of a Green Inhi...       Dobhal, Harsh
#
#                   Supervisor   Degree    Department  \
# 0                Rai, Piyush    PH.D.           CSE
# 1          Shekhar, Shashank  M.TECH.           MSE
# 2            Singh, Jayant K  M.TECH.           CHE
# 3      Jagannatham, Aditya K  M.TECH.            EE
# 4         Goswami, Debabrata  M.TECH.          CELP
# ...                      ...      ...           ...
# 17288             Kapur, J N    PH.D.  MATH & STATS
# 17289             Kapur, J N    PH.D.  MATH & STATS
# 17290            Sharma, K K    PH.D.           PHY
# 17291               Abhishek    PH.D.            AE
# 17292          Misra, Sudhir  M.TECH.            CE
#
#                                                 Abstract
# 0      ['class', 'learning', 'generative', 'shot', 'd...
# 1      ['material', 'recrystallization', 'ductility',...
# 2      ['soil', 'nir', 'nutrient', 'fertilizer', 'dev...
# 3      ['sensor', 'fusion', 'constraint', 'snr', 'tec...
# 4      ['nonlinear', 'methanol', 'laser', 'beam', 'op...
# ...                                                  ...
# 17288  ['lubricant', 'bearing', 'conducting', 'fluid'...
# 17289  ['fluid', 'viscoelastic', 'newtonian', 'steady...
# 17290  ['dye', 'chapter', 'grating', 'laser', 'doped'...
# 17291  ['flight', 'uav', 'controller', 'hils', 'helic...
# 17292  ['corrosion', 'rebar', 'extract', 'concrete', ...
#
# [17293 rows x 8 columns]

# %% [markdown]
# ### Importing data is complete and the common part of the code starts

# %%
data
# Out:
#        Unnamed: 0 Submission Date  \
# 0               0     30-Sep-2020
# 1               1     24-Sep-2020
# 2               2     19-Sep-2020
# 3               3     15-Sep-2020
# 4               4     15-Sep-2020
# ...           ...             ...
# 17288       17288     25-Apr-1964
# 17289       17289     25-Feb-1964
# 17290       17290     29-Dec-1963
# 17291       17291     21-Dec-  18
# 17292       17292     22-Jul-   7
#
#                                                    Title              Author  \
# 0      Generative Models for Zero-Shot and Generalize...  Verma, Vinay Kumar
# 1      Recrystallization As a Defect Healing Techniqu...     Vishal, Utkarsh
# 2      Development of a rapid soil testing tool for r...        Ahmad, Ashar
# 3      Optimal Hybrid Precoder Designs for the Linear...  Raghubabu, Akarapu
# 4      Discernment of the Induced Third Order Optical...   Chaturvedi, Umang
# ...                                                  ...                 ...
# 17288  CONTRIBUTIONS TO HYDRODYNAMIC AND HYDROMAGNETI...         Shukla, J B
# 17289  STEADY AND UNSTEADY FLOWS OF NEWTONIAN, NON-NE...     Srivastava, P N
# 17290  CONTINUOUS WAVE NON-LINEAR OPTICAL STUDIES IN ...     Rao, K Divakara
# 17291  Modeling, hardware-in-the-loop simulation and ...         Setu, Sagar
# 17292  Identification and Application of a Green Inhi...       Dobhal, Harsh
#
#                   Supervisor   Degree    Department  \
# 0                Rai, Piyush    PH.D.           CSE
# 1          Shekhar, Shashank  M.TECH.           MSE
# 2            Singh, Jayant K  M.TECH.           CHE
# 3      Jagannatham, Aditya K  M.TECH.            EE
# 4         Goswami, Debabrata  M.TECH.          CELP
# ...                      ...      ...           ...
# 17288             Kapur, J N    PH.D.  MATH & STATS
# 17289             Kapur, J N    PH.D.  MATH & STATS
# 17290            Sharma, K K    PH.D.           PHY
# 17291               Abhishek    PH.D.            AE
# 17292          Misra, Sudhir  M.TECH.            CE
#
#                                                 Abstract
# 0      ['class', 'learning', 'generative', 'shot', 'd...
# 1      ['material', 'recrystallization', 'ductility',...
# 2      ['soil', 'nir', 'nutrient', 'fertilizer', 'dev...
# 3      ['sensor', 'fusion', 'constraint', 'snr', 'tec...
# 4      ['nonlinear', 'methanol', 'laser', 'beam', 'op...
# ...                                                  ...
# 17288  ['lubricant', 'bearing', 'conducting', 'fluid'...
# 17289  ['fluid', 'viscoelastic', 'newtonian', 'steady...
# 17290  ['dye', 'chapter', 'grating', 'laser', 'doped'...
# 17291  ['flight', 'uav', 'controller', 'hils', 'helic...
# 17292  ['corrosion', 'rebar', 'extract', 'concrete', ...
#
# [17293 rows x 8 columns]

# %%
count = CountVectorizer()
# count = CountVectorizer(max_features=500)
counts = count.fit_transform(data['Abstract'])
counts
# Out:
# <17293x76131 sparse matrix of type '<class 'numpy.int64'>'
# 	with 517361 stored elements in Compressed Sparse Row format>

# %%
counts.shape
# Out:
# (17293, 76131)

# %%
count.get_feature_names()
# Out:
# ['aa',
#  'aaa',
#  'aab',
#  'aac',
#  'aacfs',
#  'aachen',
#  'aad',
#  'aadt',
#  'aag',
#  'aahp',
#  'aal',
#  'aalap',
#  'aalb',
#  'aam',
#  'aamic',
#  'aamir',
#  'aams',
#  'aan',
#  'aao',
#  'aap',
#  'aaqms',
#  'aarogyasri',
#  'aaroh',
#  'aaronson',
#  'aasho',
#  'aatp',
#  'aav',
#  'ab',
#  'aba',
#  'abab',
#  'abacus',
#  'abandon',
#  'abandoned',
#  'abandonment',
#  'abandwidth',
#  'abank',
#  'abanyan',
#  'abaqus',
#  'abase',
#  'abastract',
#  'abatement',
#  'abatementprogrammes',
#  'abb',
#  'abba',
#  'abbe',
#  'abbott',
#  'abbreviate',
#  'abbreviated',
#  'abbreviating',
#  'abbreviation',
#  'abc',
#  'abcd',
#  'abd',
#  'abdomen',
#  'abdominal',
#  'abduction',
#  'abductive',
#  'abductor',
#  'abe',
#  'abeb',
#  'abehavioral',
#  'abel',
#  'abeli',
#  'abelian',
#  'abelin',
#  'aber',
#  'aberrant',
#  'aberration',
#  'abetted',
#  'abettercoke',
#  'abf',
#  'abhava',
#  'abhinavagupta',
#  'abhor',
#  'abi',
#  'abiad',
#  'abietate',
#  'abietic',
#  'abilinear',
#  'abilit',
#  'ability',
#  'abinary',
#  'abiotic',
#  'abiotically',
#  'abituminous',
#  'abl',
#  'ablanking',
#  'ablate',
#  'ablated',
#  'ablating',
#  'ablation',
#  'ablationregime',
#  'ablative',
#  'able',
#  'abled',
#  'ables',
#  'ableto',
#  'ablockage',
#  'ably',
#  'abm',
#  'abmissible',
#  'abnormal',
#  'abnormality',
#  'abnormally',
#  'abo',
#  'aboard',
#  'abode',
#  'abola',
#  'abolished',
#  'abolishes',
#  'abomber',
#  'aborated',
#  'aboratory',
#  'aborption',
#  'abort',
#  'abortion',
#  'abottom',
#  'abou',
#  'aboutarmy',
#  'aboutthem',
#  'abov',
#  'aboveare',
#  'aboveassumptions',
#  'aboveconclusions',
#  'abovecriteria',
#  'abovediscussed',
#  'aboveexperiments',
#  'abovefields',
#  'abovemarker',
#  'abovementioned',
#  'abovemethod',
#  'abovemethods',
#  'aboveproblem',
#  'aboverequirement',
#  'abovetechniques',
#  'abovethe',
#  'abovetype',
#  'abp',
#  'abpe',
#  'abps',
#  'abr',
#  'abradable',
#  'abrade',
#  'abrading',
#  'abraham',
#  'abrahamson',
#  'abramowicz',
#  'abraser',
#  'abrasi',
#  'abrasion',
#  'abrasionresistance',
#  'abrasive',
#  'abrasivecosts',
#  'abricate',
#  'abrication',
#  'abridge',
#  'abrief',
#  'abrikosov',
#  'abroad',
#  'abrogates',
#  'abrupt',
#  'abruptly',
#  'abscissa',
#  'absence',
#  'absenceof',
#  'absent',
#  'absenteeism',
#  'absfurther',
#  'abso',
#  'absolute',
#  'absolutegeneral',
#  'absolutely',
#  'absolutelyconvergent',
#  'absolve',
#  'absorb',
#  'absorbance',
#  'absorbed',
#  'absorbent',
#  'absorber',
#  'absorberplate',
#  'absorbing',
#  'absorbs',
#  'absorbtion',
#  'absorbtivity',
#  'absorp',
#  'absorption',
#  'absorptionand',
#  'absorptioncharacteristics',
#  'absorptionenhancement',
#  'absorptionevents',
#  'absorptionspectrum',
#  'absorptionwith',
#  'absorptive',
#  'absorptivity',
#  'abstarct',
#  'abstract',
#  'abstracta',
#  'abstractcomputational',
#  'abstractconversing',
#  'abstractcryptanalysis',
#  'abstractdistributed',
#  'abstracted',
#  'abstractgiven',
#  'abstractheart',
#  'abstracthelp',
#  'abstractif',
#  'abstractin',
#  'abstracting',
#  'abstraction',
#  'abstractionsof',
#  'abstractive',
#  'abstractlearnability',
#  'abstractmcs',
#  'abstractminimization',
#  'abstractness',
#  'abstractparallel',
#  'abstractproper',
#  'abstractremoval',
#  'abstractretaining',
#  'abstractsolution',
#  'abstractsoundness',
#  'abstractspeech',
#  'abstracttesting',
#  'abstractthe',
#  'abstractthis',
#  'abstracttoday',
#  'abstractunderstanding',
#  'abstractvisibly',
#  'abstractwe',
#  'abstraetin',
#  'abstration',
#  'abstrct',
#  'abstruse',
#  'abt',
#  'abtianed',
#  'abulated',
#  'abulating',
#  'abundance',
#  'abundancy',
#  'abundant',
#  'abundantly',
#  'abundence',
#  'abundle',
#  'abundleof',
#  'abuse',
#  'abut',
#  'abutm',
#  'abutment',
#  'abutting',
#  'abx',
#  'ac',
#  'aca',
#  'acac',
#  'acacia',
#  'academia',
#  'academic',
#  'academically',
#  'academician',
#  'academy',
#  'acadinnet',
#  'acantilever',
#  'acarbose',
#  'acb',
#  'acbs',
#  'acc',
#  'acce',
#  'accelectrometers',
#  'acceler',
#  'accelerate',
#  'accelerated',
#  'accelerates',
#  'accelerating',
#  'acceleration',
#  'accelerationapproach',
#  'accelerationhave',
#  'accelerationof',
#  'accelerationresponse',
#  'accelerative',
#  'accelerator',
#  'accelero',
#  'accelerogram',
#  'accelerograms',
#  'accelerographs',
#  'accelerometer',
#  'accent',
#  'accentuates',
#  'accentuating',
#  'accentuation',
#  'accep',
#  'accept',
#  'acceptability',
#  'acceptabl',
#  'acceptable',
#  'acceptableaccuracy',
#  'acceptably',
#  'acceptance',
#  'acceptancecontrol',
#  'accepted',
#  'acceptence',
#  'accepting',
#  'acceptor',
#  'acceptorless',
#  'accepts',
#  'acces',
#  'access',
#  'accessanalysis',
#  'accesscards',
#  'accessed',
#  'accessi',
#  'accessibil',
#  'accessibility',
#  'accessible',
#  'accessing',
#  'accession',
#  'accessory',
#  'accessprotocols',
#  'accident',
#  'accidental',
#  'accidentally',
#  'accidently',
#  'acclaimed',
#  'accleration',
#  'acclimatized',
#  'acco',
#  'accom',
#  'accommodate',
#  'accommodated',
#  'accommodates',
#  'accommodating',
#  'accommodation',
#  'accommodative',
#  'accomodate',
#  'accomodation',
#  'accompanie',
#  'accompanied',
#  'accompaniedby',
#  'accompaniers',
#  'accompanies',
#  'accompaniment',
#  'accompany',
#  'accompanying',
#  'accompanyling',
#  'accomplish',
#  'accomplished',
#  'accomplishes',
#  'accomplishing',
#  'accomplishment',
#  'accompolished',
#  'accor',
#  'accord',
#  'accordance',
#  'accorded',
#  'accordi',
#  'accordin',
#  'according',
#  'accordingl',
#  'accordingly',
#  'accordingto',
#  'accordion',
#  'accou',
#  'accoun',
#  'account',
#  'accountability',
#  'accountable',
#  'accounted',
#  'accountedfor',
#  'accountfactors',
#  'accounting',
#  'accountsfor',
#  'accountthe',
#  'accredited',
#  'accretion',
#  'accretionary',
#  'accretive',
#  'accrued',
#  'accrues',
#  'accruing',
#  'accu',
#  'accuimilated',
#  'acculturation',
#  'acculturative',
#  'accumulate',
#  'accumulated',
#  'accumulates',
#  'accumulatesmaximum',
#  'accumulating',
#  'accumulation',
#  'accumulative',
#  'accumulator',
#  'accur',
#  'accura',
#  'accurac',
#  'accuracy',
#  'accuracyachievable',
#  'accuracyfor',
#  'accuracyobtained',
#  'accuracyof',
#  'accuracyschemes',
#  'accuracyup',
#  'accuracywith',
#  'accurat',
#  'accurate',
#  'accuratecomputional',
#  'accurately',
#  'accuratelycapture',
#  'accuratelyidentify',
#  'accuratelyreproduced',
#  'accuratemanner',
#  'accuratemeasurement',
#  'accurateresult',
#  'accuratesimulation',
#  'accuratestress',
#  'accuratetomograms',
#  'accurently',
#  'accurring',
#  'accus',
#  'accuse',
#  'accustomed',
#  'acd',
#  'acdenturates',
#  'ace',
#  'acelate',
#  'acelp',
#  'acement',
#  'acentral',
#  'acentric',
#  'acetabular',
#  'acetal',
#  'acetaldehyde',
#  'acetamide',
#  'acetamido',
#  'acetat',
#  'acetate',
#  'acetatemembranes',
#  'acetato',
#  'aceti',
#  'acetic',
#  'acetoacetate',
#  'acetogenic',
#  'acetolysis',
#  'acetone',
#  'acetonide',
#  'acetonitrile',
#  'acetonitriles',
#  'acetophenone',
#  'acetoxy',
#  'acetoxyglucal',
#  'acetoxyl',
#  'acetoxymethyl',
#  'acetyl',
#  'acetylacetonate',
#  'acetylacetone',
#  'acetylated',
#  'acetylation',
#  'acetylcholine',
#  'acetylene',
#  'acetylglucosamine',
#  'acetyltransferase',
#  'acf',
#  'acfincluded',
#  'acfs',
#  'acg',
#  'acgn',
#  'ach',
#  'achallenging',
#  'achange',
#  'acharacterization',
#  'acharya',
#  'ache',
#  'acheive',
#  'acheivements',
#  'achi',
#  'achie',
#  'achievability',
#  'achievable',
#  'achievablenetwork',
#  'achieve',
#  'achieveaccurate',
#  'achieved',
#  'achievedresults',
#  'achievehigh',
#  'achievement',
#  'achieveminimum',
#  'achievenear',
#  'achiever',
#  'achieves',
#  'achievespeaker',
#  'achievethe',
#  'achievi',
#  'achieving',
#  'achievinghigh',
#  'achine',
#  'achiral',
#  'achived',
#  'aci',
#  'acicular',
#  'acid',
#  'acidenvironments',
#  'acidic',
#  'acidification',
#  'acidified',
#  'acidifier',
#  'acidite',
#  'acidity',
#  'acidol',
#  'acility',
#  'acing',
#  'acitic',
#  'acity',
#  'ack',
#  'ackermann',
#  'acking',
#  'ackled',
#  'acknowledge',
#  'acknowledged',
#  'acknowledgement',
#  'acknowledges',
#  'acknowledgment',
#  'ackroyd',
#  'acl',
#  'acld',
#  'acleaned',
#  'aclick',
#  'acloseness',
#  'aclr',
#  'aclustering',
#  'acm',
#  'acmap',
#  'acme',
#  'acml',
#  'acms',
#  'aco',
#  'acode',
#  'acoding',
#  'acoh',
#  'acollection',
#  'acollective',
#  'acombination',
#  'acombustor',
#  'acommon',
#  'acommunication',
#  'acommunity',
#  'acompact',
#  'acomparison',
#  'acomplex',
#  'acompliant',
#  'acomplimentary',
#  'acomponent',
#  'acompound',
#  'acomputational',
#  'acomputer',
#  'aconcentrated',
#  'aconductivity',
#  'aconsiderable',
#  'aconstant',
#  'aconstraint',
#  'acontainer',
#  'acontrol',
#  'aconventional',
#  'aconversion',
#  'aconyne',
#  'acoo',
#  'acoolant',
#  'acorrection',
#  'acorrelation',
#  'acorresponding',
#  'acost',
#  'acots',
#  'acoupled',
#  'acoust',
#  'acoustic',
#  'acoustical',
#  'acoustically',
#  'acousticdomain',
#  'acousticlevels',
#  'acousto',
#  'acoustoelastic',
#  'acp',
#  'acpar',
#  'acptdfs',
#  'acq',
#  'acqt',
#  'acquaintance',
#  'acquainted',
#  'acquaints',
#  'acquirable',
#  'acquire',
#  'acquired',
#  'acquiredfrom',
#  'acquires',
#  'acquiring',
#  'acquisi',
#  'acquisition',
#  'acquisitioncould',
#  'acquisitionproblem',
#  'acquistion',
#  'acr',
#  'acrack',
#  'acrage',
#  'acrb',
#  'acre',
#  'acreage',
#  'acridine',
#  'acrifice',
#  'acrl',
#  'acrobatic',
#  'acrobatics',
#  'acronym',
#  'across',
#  'acrosssparallel',
#  'acrossthe',
#  'acrossuction',
#  'acrylamide',
#  'acrylate',
#  'acrylic',
#  'acrylo',
#  'acrylonitrile',
#  'acryloyl',
#  'acryloyloxazolidin',
#  'acsl',
#  'acsr',
#  'act',
#  'acta',
#  'actable',
#  'acted',
#  'acteristic',
#  'acteristics',
#  'acterize',
#  'acti',
#  'actic',
#  'actidione',
#  'actin',
#  'acting',
#  'actingat',
#  'actinide',
#  'action',
#  'actionable',
#  'actionclasses',
#  'actionmodel',
#  'actionof',
#  'actionplan',
#  'actionssuch',
#  'activ',
#  'activa',
#  'activat',
#  'activate',
#  'activated',
#  'activatedalumina',
#  'activates',
#  'activating',
#  'activatingagent',
#  'activatingor',
#  'activatio',
#  'activation',
#  'activationenergies',
#  'activationenergy',
#  'activationresulted',
#  'activaton',
#  'activator',
#  'active',
#  'activeeven',
#  'activefilter',
#  'activelayer',
#  'activeloop',
#  'actively',
#  'activepower',
#  'activeregions',
#  'activeresearch',
#  'activevariables',
#  'activi',
#  'activin',
#  'activist',
#  'activity',
#  'activitylevel',
#  'activmedia',
#  'actor',
#  'actorily',
#  'actory',
#  'actransmission',
#  'actsalong',
#  'actu',
#  'actual',
#  'actualcharacteristics',
#  'actualcollapse',
#  'actualconsumption',
#  'actualevapotranspiration',
#  'actualholdups',
#  'actuality',
#  'actualization',
#  'actually',
#  'actuallyreach',
#  'actualmulti',
#  'actualoperation',
#  'actualschedule',
#  'actualshape',
#  'actualvalues',
#  'actuate',
#  'actuated',
#  'actuates',
#  'actuating',
#  'actuation',
#  'actuator',
#  'actuatorposition',
#  'actuatorsand',
#  'acture',
#  'acute',
#  'acutely',
#  'acutus',
#  'acvs',
#  'acy',
#  'acycle',
#  'acyclic',
#  'acyclicity',
#  'acyl',
#  'acylated',
#  'acylation',
#  'acylinder',
#  'acylketene',
#  'acyloins',
#  'aczel',
#  'ad',
#  'ada',
#  'adachi',
#  'adaline',
#  'adam',
#  'adamantane',
#  'adani',
#  'adap',
#  'adapt',
#  'adaptability',
#  'adaptable',
#  'adaptation',
#  'adaptationhas',
#  'adaptationsin',
#  'adapted',
#  'adapter',
#  'adapting',
#  'adaption',
#  'adaptiv',
#  'adaptive',
#  'adaptiveanalysis',
#  'adaptively',
#  'adaptivelyselecting',
#  'adaptiveness',
#  'adaptiver',
#  'adaptiverefinement',
#  'adaptivesequential',
#  'adaptivity',
#  'adaptor',
#  'adapts',
#  'adaptsquickly',
#  'adart',
#  'adata',
#  'adatabase',
#  'adatom',
#  'adatoms',
#  'adaunting',
#  'aday',
#  'adb',
#  'adc',
#  'adcc',
#  'adcs',
#  'add',
#  'added',
#  'addedadvantage',
#  'addeed',
#  'adder',
#  'addi',
#  'addiction',
#  'adding',
#  'addit',
#  'additi',
#  'additio',
#  'addition',
#  'additional',
#  'additionalconstraints',
#  'additionalexperiments',
#  'additionalhardware',
#  'additionall',
#  'additionally',
#  'additionallydetailed',
#  'additionaloperations',
#  'additionto',
#  'additive',
#  'additively',
#  'additons',
#  'addoms',
#  'addon',
#  'addr',
#  'address',
#  'addressability',
#  'addressable',
#  'addressallocation',
#  'addresscodes',
#  'addressed',
#  'addressedhere',
#  'addressenvironmental',
#  'addressesthe',
#  'addressesthis',
#  'addressing',
#  'addressre',
#  'addressthe',
#  'adduct',
#  'adduction',
#  'adductive',
#  'adductstage',
#  'ade',
#  'adecreasein',
#  'adeformable',
#  'adeformation',
#  'adegree',
#  'adelaide',
#  'adelivery',
#  'adelta',
#  'adenine',
#  'adenocarcinoma',
#  'adenosine',
#  'adenylated',
#  'adependence',
#  'adependencies',
#  'adependent',
#  'adept',
#  'adequa',
#  'adequacy',
#  'adequacyfor',
#  'adequal',
#  'adequate',
#  'adequately',
#  'adequatemethod',
#  'adequateresolution',
#  'adequateworkability',
#  'ader',
#  'adesign',
#  'adetailed',
#  'adetector',
#  'adevice',
#  'adfe',
#  'adges',
#  'adhe',
#  'adhere',
#  'adhered',
#  'adherence',
#  'adherend',
#  'adherends',
#  'adherent',
#  'adheres',
#  'adhering',
#  'adhesin',
#  'adhesins',
#  'adhesion',
#  'adhesive',
#  'adhesiveconfined',
#  'adhesiveinterface',
#  'adhesively',
#  'adhesiveof',
#  'adhoc',
#  'adhocracy',
#  'adi',
#  'adiabatic',
#  'adiabatically',
#  'adic',
#  'adidam',
#  'adifferent',
#  'adifferential',
#  'adigital',
#  'adilabad',
#  'adily',
#  'ading',
#  'adipic',
#  'adipogenic',
#  'adipose',
#  'adirected',
#  'adiscontinuity',
#  'adiscontinuous',
#  'adiscussion',
#  'adisplacement',
#  'adistance',
#  'adistributed',
#  'adistribution',
#  'adisturbance',
#  'aditya',
#  'adivasi',
#  'adiversity',
#  'adivision',
#  'adjac',
#  'adjacency',
#  'adjacencymatrix',
#  'adjacent',
#  'adjectival',
#  'adjoin',
#  'adjoined',
#  'adjoining',
#  'adjoint',
#  'adjoints',
#  'adju',
#  'adjudge',
#  'adjudged',
#  'adjudging',
#  'adjudicating',
#  'adjunct',
#  'adjust',
#  'adjustable',
#  'adjusted',
#  'adjustement',
#  'adjuster',
#  'adjusting',
#  'adjustment',
#  'adjusts',
#  'adjuvant',
#  'adl',
#  'adlayer',
#  'adleman',
#  'adler',
#  'adm',
#  'admc',
#  'admd',
#  'admin',
#  'administer',
#  'administered',
#  'administering',
#  'administrating',
#  'administration',
#  'administrative',
#  'administrator',
#  'admirable',
#  'admirably',
#  'admired',
#  'admissibility',
#  'admissible',
#  'admission',
#  'admit',
#  'admits',
#  'admittance',
#  'admitted',
#  'admittedly',
#  'admitting',
#  'admixed',
#  'admixture',
#  'admm',
#  'adn',
#  'adnet',
#  'adnr',
#  'adobe',
#  'adolescent',
#  'adomain',
#  'adomestic',
#  'adomian',
#  'adon',
#  'adopt',
#  'adoptability',
#  'adopted',
#  'adoptedin',
#  'adoptedto',
#  'adopter',
#  'adopting',
#  'adoptingcentral',
#  'adoption',
#  'adoptive',
#  'adopts',
#  'adore',
#  'adouble',
#  'adoubled',
#  'adp',
#  'adpative',
#  'adr',
#  'adrasive',
#  'adratic',
#  'adrde',
#  'adscs',
#  'adso',
#  'adsop',
#  'adsor',
#  'adsorb',
#  'adsorbate',
#  'adsorbe',
#  'adsorbed',
#  'adsorbent',
#  'adsorber',
#  'adsorberperformance',
#  'adsorbing',
#  'adsorbtion',
#  'adsorpting',
#  'adsorption',
#  'adsorptionand',
#  'adsorptioncolumn',
#  'adsorptive',
#  'adsp',
#  'adt',
#  'adts',
#  'adtt',
#  'adult',
#  'adulteration',
#  'adulthood',
#  'adunctin',
#  'adv',
#  'adva',
#  'advaita',
#  'advan',
#  'advanc',
#  'advance',
#  ...]

# %%
tfidftransformer = TfidfTransformer()
transformed_matrix = tfidftransformer.fit_transform(counts)
transformed_matrix
# Out:
# <17293x76131 sparse matrix of type '<class 'numpy.float64'>'
# 	with 517361 stored elements in Compressed Sparse Row format>

# %%
print(transformed_matrix)
# Out:
#   (0, 75934)	0.16329695422744686
#   (0, 71516)	0.2240177163994079
#   (0, 69121)	0.15868154235333448
#   (0, 63430)	0.21303873885451552
#   (0, 60712)	0.20205976130962316
#   (0, 59936)	0.21984370285666457
#   (0, 59570)	0.16282189835248712
#   (0, 59142)	0.19581775917218996
#   (0, 58221)	0.17785741641277902
#   (0, 51685)	0.10197432876975208
#   (0, 51592)	0.2289545265908699
#   (0, 47995)	0.17955031077451436
#   (0, 43906)	0.16743105989217424
#   (0, 42441)	0.1477025648084421
#   (0, 39233)	0.19745932178332512
#   (0, 36019)	0.14600558851554168
#   (0, 31304)	0.24278640247989547
#   (0, 26258)	0.20012483190323896
#   (0, 25210)	0.14587935290073992
#   (0, 23012)	0.1679951946788687
#   (0, 22714)	0.21622800786381266
#   (0, 22643)	0.1848387816272976
#   (0, 18266)	0.12975447153593192
#   (0, 15740)	0.168571333229622
#   (0, 15242)	0.10859504323904179
#   :	:
#   (17292, 61852)	0.12184268785679199
#   (17292, 60528)	0.11048207485912355
#   (17292, 58645)	0.19739595632941195
#   (17292, 57237)	0.20607168971610684
#   (17292, 54941)	0.1467244423089087
#   (17292, 54177)	0.22333681908409586
#   (17292, 50914)	0.17736038363701462
#   (17292, 50757)	0.14093744387900892
#   (17292, 50565)	0.146916785477194
#   (17292, 42441)	0.13587013382107171
#   (17292, 40267)	0.20607168971610684
#   (17292, 40264)	0.19213260254089964
#   (17292, 31893)	0.17940879621786318
#   (17292, 31889)	0.21949718515926175
#   (17292, 31851)	0.21061301276105937
#   (17292, 22762)	0.16682773135434847
#   (17292, 19866)	0.1299429847696513
#   (17292, 19177)	0.1840928607223375
#   (17292, 17381)	0.1946255130050036
#   (17292, 13859)	0.1515742314202042
#   (17292, 12696)	0.13861871815634616
#   (17292, 11960)	0.18778975318764984
#   (17292, 10797)	0.25070140170245797
#   (17292, 9552)	0.21323736583372274
#   (17292, 6150)	0.1933478833930704

# %% [markdown]
# ### Visualizing Features - Using tsne

# %%
transformed_matrix
# Out:
# <17293x76131 sparse matrix of type '<class 'numpy.float64'>'
# 	with 517361 stored elements in Compressed Sparse Row format>

# %%
from sklearn.manifold import TSNE

# %%
# %%time
tsne = TSNE(init='random', random_state=0)

reduced_features= tsne.fit_transform(transformed_matrix)

print(reduced_features)
print(reduced_features.shape)

# %%
plt.scatter(reduced_features[:,0], reduced_features[:,1])
plt.show()

# %%
# %%time
kmeans = KMeans(n_clusters = 50,init='k-means++', random_state=0)
# kmeans.fit(reduced_features)
# kmeans.fit(transformed_matrix)
predicted = kmeans.fit_transform(reduced_features)

centers = kmeans.cluster_centers_
# predicted

# %%
# print(kmeans.labels_)
# print(centers.shape)

plt.scatter(reduced_features[:,0], reduced_features[:,1], c=kmeans.labels_)
plt.scatter(centers[:,0], centers[:,1], marker='x')
plt.xlabel('TSNE-1')
plt.xlabel('TSNE-2')
plt.title('Clustering of entire dataset')
plt.show()

# %%
labels = kmeans.labels_
labels = labels.tolist()
temp = Counter(labels)
# temp

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
for i in range(50):
    ax.bar(i, temp[i], color='r')
# plt.show()
plt.xlabel('Cluster')
plt.ylabel('Count')
plt.title('No of Articles in each cluster')

# %%
len(kmeans.labels_)
labels = kmeans.labels_
# labels = labels[labels == 0]
len(labels)

cluster1 = np.where(labels == 0)
cluster1

# np.unique(labels)

# %% [markdown]
# kmeans.n_iter_

# %% [markdown]
# ### Visualization using UMAP

# %%
import umap


umap_model = umap.UMAP(random_state=0)
reduced_features= umap_model.fit_transform(transformed_matrix)

print(reduced_features.shape)
# Out:
# (17981, 2)

# %%
plt.scatter(reduced_features[:,0], reduced_features[:,1])
plt.show()

# %%
# %%time
kmeans = KMeans(n_clusters = 45,init='k-means++')
kmeans.fit(reduced_features)
centers = kmeans.cluster_centers_
# centers
# Out:
# Wall time: 1.96 s

# %%
# print(kmeans.labels_)
# print(centers.shape)

plt.scatter(reduced_features[:,0], reduced_features[:,1], c=kmeans.labels_)
plt.scatter(centers[:,0], centers[:,1], marker='x')
plt.show()
