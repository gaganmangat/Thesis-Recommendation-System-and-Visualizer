# %%
import pandas as pd
import numpy as np
import csv
df=pd.read_csv('../Pre-Processing/data_cleaned.csv')

# %%
df.dtypes
# Out:
# id             int64
# Title         object
# Author        object
# Supervisor    object
# Degree        object
# Department    object
# Abstract      object
# Date           int64
# URL           object
# dtype: object

# %%
df.head(2)
# Out:
#    id                                              Title              Author  \
# 0   0  Effect of Acoustic perturbation on the Transit...  Tiwari, Akhilesh S
# 1   1  Design of Graphene and Carbon Black Based Plan...       Arora, Mayank
#
#          Supervisor   Degree Department  \
# 0     Kumar, Sanjay  M.TECH.         AE
# 1  Akhtar, M Jaleel  M.TECH.        MSP
#
#                                             Abstract  Date  \
# 0  An experimental study of the effect of acousti...  2020
# 1  The application of attenuators in the RF and m...  2020
#
#                                                  URL
# 0  http://172.28.64.70:8080/jspui/handle/12345678...
# 1  http://172.28.64.70:8080/jspui/handle/12345678...

# %%
df['count']=1
df1=df.groupby(['Date','Department'],as_index=False).agg({'count':'sum'})
df1.sort_values(by=['Date','Department'],inplace=True)

# %%
len(df)
# Out:
# 17311

# %%
len(df1)
# Out:
# 828

# %%
df1.head(3)
# Out:
#    Date    Department  count
# 0  1965  MATH & STATS      1
# 1  1966            CE      2
# 2  1966            EE      6

# %%
dep=set(df['Department'])

# %%
len(dep)
# Out:
# 27

# %%
dep
# Out:
# {'AE',
#  'BSBE',
#  'CE',
#  'CELP',
#  'CHE',
#  'CHM',
#  'CSE',
#  'Civil',
#  'DES',
#  'DP',
#  'ECO',
#  'EE',
#  'EEM',
#  'EEMP',
#  'ES',
#  'HSS',
#  'IME',
#  'LT',
#  'LTP',
#  'MATH & STATS',
#  'ME',
#  'MME',
#  'MSE',
#  'MSP',
#  'NET',
#  'NETP',
#  'PHY'}

# %%
df.tail(3)
# Out:
#           id                                              Title  \
# 17308  17308  VIBRATIONS OF A DEEP BEAM WITH CENTRALLY ATTAC...
# 17309  17309  SOME ASPECTS OF SUPERPOSASBILITY IN FLUID DYNA...
# 17310  17310  STEADY AND UNSTEADY FLOWS OF ELECTRICALLY COND...
#
#                             Author                Supervisor   Degree  \
# 17308  Deshmukh, Rajabhau Sheshrao  Das, Yellaapa Chidananda  M.TECH.
# 17309           Bhatia, Baldve Lal                Kapur, J N    PH.D.
# 17310              Kumar, Rajender                Kapur, J N    PH.D.
#
#          Department                                           Abstract  Date  \
# 17308            CE  The aim of this thesis is to study the vibrati...  1966
# 17309  MATH & STATS  The present thesis deals with superposability ...  1966
# 17310  MATH & STATS  The present thesis deals with the steady and u...  1965
#
#                                                      URL  count
# ...

# %%
df1.tail(3)
# Out:
#      Date Department  count
# 825  2020        MSE     16
# 826  2020        MSP     10
# 827  2020        PHY      6

# %%
df2=df1.groupby(df1.Department)

# %%
df2.get_group("CSE")
# Out:
#      Date Department  count
# 63   1973        CSE      2
# 74   1974        CSE      6
# 86   1975        CSE      5
# 99   1976        CSE     10
# 113  1977        CSE      9
# 127  1978        CSE     15
# 141  1979        CSE      8
# 155  1980        CSE     13
# 169  1981        CSE     11
# 183  1982        CSE     15
# 197  1983        CSE     13
# 211  1984        CSE     13
# 225  1985        CSE     21
# 239  1986        CSE     11
# 253  1987        CSE     12
# 267  1988        CSE     16
# 281  1989        CSE     14
# 295  1990        CSE     20
# 310  1991        CSE     25
# 324  1992        CSE     26
# 340  1993        CSE     30
# 355  1994        CSE     17
# 370  1995        CSE     28
# 385  1996        CSE     27
# 401  1997        CSE     30
# 416  1998        CSE     28
# 431  1999        CSE     22
# 447  2000        CSE     25
# 462  2001        CSE     45
# 477  2002        CSE     19
# 494  2003        CSE     28
# 510  2004        CSE     18
# ...

# %%
dep=list(dep)

# %%
depcount=df1.groupby(['Department'],as_index=False).agg({'count':'sum'})

# %%
depcount
# Out:
#       Department  count
# 0             AE   1097
# 1           BSBE    254
# 2             CE   2251
# 3           CELP     17
# 4            CHE   1571
# 5            CHM    577
# 6            CSE   1568
# 7          Civil      1
# 8            DES    218
# 9             DP     46
# 10           ECO     44
# 11            EE   3370
# 12           EEM    113
# 13          EEMP     66
# 14            ES     48
# 15           HSS    274
# 16           IME    627
# 17            LT     62
# 18           LTP     96
# 19  MATH & STATS    331
# 20            ME   2458
# 21           MME    834
# 22           MSE    304
# 23           MSP    471
# 24           NET     74
# 25          NETP    137
# 26           PHY    402

# %%
df.loc[df['Department']=='Civil']
# Out:
#         id                                              Title        Author  \
# 7696  7696  Mathematical Modeling of Propagation of a Soli...  Paul, Avijit
#
#                              Supervisor   Degree Department  \
# 7696  Mohapatra, Pranab K; Saha, Arun K  M.TECH.      Civil
#
#                                                Abstract  Date  \
# 7696  Mathematical model of propagation of a solitar...  2008
#
#                                                     URL  count
# 7696  http://172.28.64.70:8080/jspui/handle/12345678...      1

# %%
import matplotlib.pyplot as plt

# %%
depcount.plot(x='Department',y='count',kind='bar')

# %%
names={}
for i in dep:
    names[i]=pd.DataFrame()
    names[i]=df2.get_group(i)

# %%
names['CSE'].plot(x='Date',y='count',kind='bar')

# %%
plt.rcParams['figure.figsize']=(10,5)

# %%
names['CSE'].plot(x='Date',y='count',kind='bar')

# %%
names.keys()
# Out:
# dict_keys(['MSE', 'EEM', 'CE', 'Civil', 'NETP', 'CSE', 'DES', 'LTP', 'ES', 'EE', 'CELP', 'MATH & STATS', 'CHE', 'CHM', 'LT', 'HSS', 'AE', 'MME', 'BSBE', 'EEMP', 'IME', 'PHY', 'DP', 'ME', 'MSP', 'ECO', 'NET'])

# %%
for i in names.keys():
    names[i].plot(x='Date',y='count',kind='bar')
    plt.title(i + ' Department Year-wise published papers count ')
    plt.xlabel('year')
    plt.ylabel('no of papers')
# Out:
# C:\Users\Krishna Mohan\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:320: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
